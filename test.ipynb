# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread(r"C:\Users\Mike's PC\Desktop\fake_epc.png")

# %%
img.shape
# Out:
# (864, 1536, 3)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray, cmap='gray')

# %%
gray.shape
# Out:
# (864, 1536)

# %%
plt.imshow(gray, cmap='gray')
